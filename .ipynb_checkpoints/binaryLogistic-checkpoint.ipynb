# %%
import numpy as np
import matplotlib.pyplot
import mnist
import scipy
import scipy.sparse.linalg
from scipy.sparse import csr_matrix
from scipy.sparse import identity
import pdb

# %%
trainX, trainY = mnist.load_mnist("training", None, './MNIST');
testX, testY = mnist.load_mnist("testing", None, './MNIST');
print("MNIST loaded")
# Out:
# MNIST loaded

# %%
#trainX = trainX[0:100, :]
#trainY = trainY[0:100]

# %%
class logistic:
    
    
    def __init__(self, eta, lamda, thresh):
        self.eta = eta;
        self.lamda = lamda;
        self.thresh = thresh;
        self.regularized = True;
        self.lossSet = np.zeros(2000);
        self.testLossSet = np.zeros(2000);
        
    def load_data(self, string, ori_X, ori_Y):
        """
        if string is "training":
            ori_X, self.Y = mnist.load_mnist("training", None, './MNIST');
        elif string is "testing":
            ori_X, self.Y = mnist.load_mnist("testing", None, './MNIST');
        """
        self.Y = ori_Y;
        s = ori_X.shape;
        self.d = s[1] * s[2] + 1;
        self.n = self.d;
        self.N = s[0];
        self.X = np.reshape(ori_X, (self.N, self.d-1));
        self.X = np.insert(self.X, 0, 1, axis=1);
        self.X_sparse = csr_matrix(self.X, shape=(self.N, self.d))
        print("Loading data " + string + " complete....")
        
    def load_test(self, testX, testY):
        self.testN = testX.shape[0];
        self.testX = np.reshape(testX, (self.testN, self.d-1));
        self.testX = np.insert(self.testX, 0, 1, axis=1);
        self.testY = testY
        
    def makeTestY(self, val):
        temp = np.array(self.testY == val, dtype=float);
        self.testY = np.reshape(temp, (self.testN, 1))
        print("Only looking at class " + str(val) + "!!!")
        
    def makeY(self, val):
        temp = np.array(self.Y == val, dtype=float);
        self.Y = np.reshape(temp, (self.N, 1))
        self.Y_sparse = csr_matrix(self.Y, shape=(self.N, 1))
        print("Testing Data : Only looking at class " + str(val) + "!!!")
    
    def initIteration(self):
        self.weights = np.zeros((self.n,1), dtype=float);
        self.iter = 0;
        self.prevLoss = 999999;
        self.weightDist = 99999;
    
    def computeTestLoss(self):
        temp = np.dot(self.testX, self.weights);
        temp[temp>100] = 100
        temp = np.exp(temp);
        self.prob1Test = temp / (1 + temp)
        self.sampleTestLoss = self.testY - self.prob1Test; 
        lttemp = np.concatenate([np.float64(self.testY==0), np.float64(self.testY==1)], axis=1);
        rttemp = np.asarray(np.concatenate([1-self.prob1Test, self.prob1Test], axis=1))
        self.testLoss = -np.sum(np.log(np.sum(lttemp * rttemp, axis=1) + 0.0000001)) + self.lamda * np.linalg.norm(self.weights); 
        self.testLossSet[self.iter]=self.testLoss
    
    def computeProb1(self):
        temp = np.dot(self.X, self.weights);
        temp[temp>100] = 100
        temp = np.exp(temp);
        self.prob1 = temp / (1 + temp)
        self.sampleLoss = self.Y - self.prob1; 
        
    def computeLoss(self):
        
        #self.loss = np.sqrt(np.sum(self.sampleLoss * self.sampleLoss) / self.N)
        lttemp = np.concatenate([np.float64(self.Y==0), np.float64(self.Y==1)], axis=1);
        rttemp = np.asarray(np.concatenate([1-self.prob1, self.prob1], axis=1))
        self.loss = -np.sum(np.log(np.sum(lttemp * rttemp, axis=1) + 0.0000001)) + self.lamda * np.linalg.norm(self.weights); 
        self.lossSet[self.iter]=self.loss
    
    def updateWeights(self, curIdx, batchSize):
        #print('Weight ' + str(curIdx) + ' : ' + str(self.weights[curIdx]))
        self.batchSize = batchSize;
        idx_from = range(0, self.N, self.batchSize)
        idx_to = idx_from[1:]
        idx_to.extend([self.N])
        
        if self.regularized:
            for x in range(0, len(idx_from)):
                self.weights[curIdx] = self.weights[curIdx] + self.eta * np.sum(self.X[idx_from[x]:idx_to[x], curIdx] * self.sampleLoss[idx_from[x]:idx_to[x],0]);
            self.weights[curIdx] = self.weights[curIdx] - self.eta * self.weights[curIdx] * self.lamda;
            #self.weights[curIdx] = self.weights[curIdx] + self.eta * (np.sum(self.X[:, curIdx] * self.sampleLoss[:,0]) - self.weights[curIdx] * self.lamda);
        else:
            for x in range(0, len(idx_from)):
                self.weights[curIdx] = self.weights[curIdx] + self.eta * np.sum(self.X[idx_from[x]:idx_to[x], curIdx] * self.sampleLoss[idx_from[x]:idx_to[x],0]);
            #self.weights[curIdx] = self.weights[curIdx] + self.eta * np.sum(self.X[:, curIdx] * self.sampleLoss[:,0]);
        #print('Weight ' + str(curIdx) + ' : ' + str(self.weights[curIdx]))
        
    def updateWeightsWhole(self, batchSize):
        self.batchSize = batchSize;
        idx_from = range(0, self.N, self.batchSize)
        idx_to = idx_from[1:]
        idx_to.extend([self.N])
        
        if self.regularized:
            #for x in range(0, len(idx_from)):
            #    self.weights = self.weights + self.eta * np.asmatrix(self.X[idx_from[x]:idx_to[x], :].transpose()) * np.asmatrix(self.sampleLoss[idx_from[x]:idx_to[x],:]) / (self.N);
            #pdb.set_trace();
            self.weights = self.weights + self.eta * np.asmatrix(self.X.transpose()) * np.asmatrix(self.sampleLoss) / (self.N);
            self.weights = self.weights - self.eta * self.weights * self.lamda;
            #self.weights = self.weights - self.eta * np.linalg.norm(self.weights[1:self.n]) * self.lamda;
            #self.weights[curIdx] = self.weights[curIdx] + self.eta * (np.sum(self.X[:, curIdx] * self.sampleLoss[:,0]) - self.weights[curIdx] * self.lamda);
        else:
            for x in range(0, len(idx_from)):
                self.weights = self.weights + self.eta * np.asmatrix(self.X[idx_from[x]:idx_to[x], :].transpose()) * self.sampleLoss[idx_from[x]:idx_to[x],:];
            #self.weights[curIdx] = self.weights[curIdx] + self.eta * np.sum(self.X[:, curIdx] * self.sampleLoss[:,0]);
        #print('Weight ' + str(curIdx) + ' : ' + str(self.weights[curIdx]))
    
    
    def distWeight(self, A, B):
        self.weightDist = scipy.linalg.norm(A - B);
        
        print("weight distance : " + str(self.weightDist));
    
    def updateWeightStochastic(self, curIdx, curSmp):
        if self.regularized:
            self.weights[curIdx] = self.weights[curIdx] + self.eta * (self.X[curSmp, curIdx] * self.sampleLoss[curSmp,0] - self.weights[curIdx] * self.lamda);
        else:
            self.weights[curIdx] = self.weights[curIdx] + self.eta * self.X[curSmp, curIdx] * self.sampleLoss[curSmp,0];
    
    def assess(self):
        self.computeProb1();
        self.pred = self.prob1 > 0.5;
        self.correct = np.sum(np.int16(self.pred == (self.Y==1)))
        self.overallAccu = np.float(self.correct) / np.float(self.N);
        self.loss01 = sum(abs(self.pred - self.Y)) / self.N
        print('Accuracy : ' + str(self.overallAccu))
        print('0 / 1 loss : ' + str(self.loss01))
    
    def genGaussFeatWeight(self, n):
        self.n = n;
        self.weight = np.random.randn(self.d, self.n);
    
    def randGaussFeatConv(self):
        self.X = np.dot(self.X, self.weight);
        
    def plotLoss(self, labelTrain, labelTest, name):
        # %matplotlib inline 
        matplotlib.pyplot.plot(np.arange(0, model.iter), model.testLossSet[0:model.iter], hold = True, color="blue", linewidth=2.0)
        matplotlib.pyplot.plot(np.arange(0, model.iter), model.lossSet[0:model.iter], hold = True, color="red", linewidth=2.0)
        matplotlib.pyplot.savefig(name, transparent = True)

# %%
model = logistic(0.1, 0.01, 1);
model.load_data("training", trainX, trainY);
model.load_test(testX, testY)
model.makeY(2);
model.makeTestY(2);
# Out:
# Loading data training complete....
# Testing Data : Only looking at class 2!!!
# Only looking at class 2!!!

# %%
model.initIteration();
model.computeProb1();
model.computeLoss();
model.computeTestLoss()
print ('Iteration 0 : Loss value ' + str(model.loss))


#while (model.weightDist > 0.01 or model.iter<3):
while (model.prevLoss - model.loss > model.thresh or model.iter<10):
    model.prevLoss = model.loss;
    model.iter = model.iter + 1;
    temp = model.weights.copy();
    
    model.updateWeightsWhole(500)
    model.computeProb1();
        
    model.computeLoss()
    model.computeTestLoss()
    model.distWeight(temp, model.weights)
    print ('Iteration ' + str(model.iter) + ' : Loss value ' + str(model.loss))
# Out:
# Iteration 0 : Loss value 41588.8188336
# weight distance : 0.237977236008
# Iteration 1 : Loss value 22271.0236388
# weight distance : 0.0558246394994
# Iteration 2 : Loss value 20731.8816755
# weight distance : 0.0380122870115
# Iteration 3 : Loss value 19938.0652924
# weight distance : 0.0319848496934
# Iteration 4 : Loss value 19347.778188
# weight distance : 0.029365456615
# Iteration 5 : Loss value 18839.7762653
# weight distance : 0.0279241668346
# Iteration 6 : Loss value 18376.3811791
# weight distance : 0.0269288053988
# Iteration 7 : Loss value 17943.7073262
# weight distance : 0.0261144694432
# Iteration 8 : Loss value 17535.9207406
# weight distance : 0.0253797397522
# Iteration 9 : Loss value 17150.1733308
# weight distance : 0.0246849053895
# Iteration 10 : Loss value 16784.7754731
# weight distance : 0.0240147189307
# Iteration 11 : Loss value 16438.4944608
# weight distance : 0.0233638429327
# Iteration 12 : Loss value 16110.2790572
# weight distance : 0.0227309011951
# Iteration 13 : Loss value 15799.1534281
# weight distance : 0.0221159868353
# Iteration 14 : Loss value 15504.1797055
# weight distance : 0.0215196169553
# Iteration 15 : Loss value 15224.4479865
# weight distance : 0.0209423079936
# Iteration 16 : Loss value 14959.0765968
# weight distance : 0.0203844198806
# Iteration 17 : Loss value 14707.2154846
# weight distance : 0.0198461155339
# Iteration 18 : Loss value 14468.0498871
# weight distance : 0.0193273679666
# Iteration 19 : Loss value 14240.803233
# weight distance : 0.0188279850969
# Iteration 20 : Loss value 14024.7390164
# weight distance : 0.018347639213
# Iteration 21 : Loss value 13819.1616809
# weight distance : 0.0178858956036
# Iteration 22 : Loss value 13623.4166629
# weight distance : 0.0174422382372
# Iteration 23 : Loss value 13436.8897692
# weight distance : 0.0170160918698
# Iteration 24 : Loss value 13259.0060499
# weight distance : 0.0166068406028
# Iteration 25 : Loss value 13089.2283103
# weight distance : 0.0162138431792
# Iteration 26 : Loss value 12927.0553778
# weight distance : 0.0158364453983
# Iteration 27 : Loss value 12772.0202174
# weight distance : 0.0154739900393
# Iteration 28 : Loss value 12623.6879703
# weight distance : 0.0151258246726
# Iteration 29 : Loss value 12481.6539713
# weight distance : 0.0147913076944
# Iteration 30 : Loss value 12345.5417864
# weight distance : 0.0144698128891
# Iteration 31 : Loss value 12215.0013021
# weight distance : 0.0141607327804
# Iteration 32 : Loss value 12089.7068876
# weight distance : 0.0138634809963
# Iteration 33 : Loss value 11969.3556421
# weight distance : 0.0135774938388
# Iteration 34 : Loss value 11853.6657392
# weight distance : 0.0133022312187
# Iteration 35 : Loss value 11742.3748691
# weight distance : 0.0130371770893
# Iteration 36 : Loss value 11635.2387823
# weight distance : 0.0127818394893
# Iteration 37 : Loss value 11532.0299321
# weight distance : 0.0125357502853
# Iteration 38 : Loss value 11432.5362141
# weight distance : 0.0122984646878
# Iteration 39 : Loss value 11336.5597981
# weight distance : 0.012069560601
# Iteration 40 : Loss value 11243.9160482
# weight distance : 0.011848637853
# Iteration 41 : Loss value 11154.432526
# weight distance : 0.0116353173459
# Iteration 42 : Loss value 11067.948071
# weight distance : 0.0114292401555
# Iteration 43 : Loss value 10984.3119542
# weight distance : 0.0112300666038
# Iteration 44 : Loss value 10903.3830985
# weight distance : 0.0110374753239
# Iteration 45 : Loss value 10825.0293613
# weight distance : 0.0108511623299
# Iteration 46 : Loss value 10749.1268752
# weight distance : 0.0106708401033
# Iteration 47 : Loss value 10675.5594409
# weight distance : 0.0104962367033
# Iteration 48 : Loss value 10604.2179692
# weight distance : 0.0103270949071
# Iteration 49 : Loss value 10534.9999676
# weight distance : 0.0101631713829
# Iteration 50 : Loss value 10467.8090682
# weight distance : 0.0100042358994
# Iteration 51 : Loss value 10402.5545928
# weight distance : 0.00985007057178
# Iteration 52 : Loss value 10339.1511528
# weight distance : 0.00970046914649
# Iteration 53 : Loss value 10277.5182806
# weight distance : 0.00955523632244
# Iteration 54 : Loss value 10217.5800899
# weight distance : 0.00941418711
# Iteration 55 : Loss value 10159.2649628
# weight distance : 0.00927714622584
# Iteration 56 : Loss value 10102.5052605
# weight distance : 0.00914394752269
# Iteration 57 : Loss value 10047.237057
# weight distance : 0.00901443345268
# Iteration 58 : Loss value 9993.39989288
# weight distance : 0.00888845456266
# Iteration 59 : Loss value 9940.93654732
# weight distance : 0.00876586902019
# Iteration 60 : Loss value 9889.79282811
# weight distance : 0.00864654216833
# Iteration 61 : Loss value 9839.91737666
# weight distance : 0.00853034610795
# Iteration 62 : Loss value 9791.26148774
# weight distance : 0.00841715930586
# Iteration 63 : Loss value 9743.77894235
# weight distance : 0.00830686622726
# Iteration 64 : Loss value 9697.42585285
# weight distance : 0.00819935699117
# Iteration 65 : Loss value 9652.16051911
# weight distance : 0.00809452704729
# Iteration 66 : Loss value 9607.94329511
# weight distance : 0.00799227687305
# Iteration 67 : Loss value 9564.73646487
# weight distance : 0.00789251168962
# Iteration 68 : Loss value 9522.50412714
# weight distance : 0.00779514119557
# Iteration 69 : Loss value 9481.2120881
# weight distance : 0.00770007931707
# Iteration 70 : Loss value 9440.82776147
# weight distance : 0.00760724397369
# Iteration 71 : Loss value 9401.32007542
# weight distance : 0.00751655685855
# Iteration 72 : Loss value 9362.65938582
# weight distance : 0.00742794323216
# Iteration 73 : Loss value 9324.81739525
# weight distance : 0.00734133172883
# Iteration 74 : Loss value 9287.76707743
# weight distance : 0.0072566541749
# Iteration 75 : Loss value 9251.48260662
# weight distance : 0.0071738454181
# Iteration 76 : Loss value 9215.9392916
# weight distance : 0.00709284316722
# Iteration 77 : Loss value 9181.11351395
# weight distance : 0.00701358784135
# Iteration 78 : Loss value 9146.98267026
# weight distance : 0.0069360224283
# Iteration 79 : Loss value 9113.52511797
# weight distance : 0.00686009235129
# Iteration 80 : Loss value 9080.7201247
# weight distance : 0.00678574534368
# Iteration 81 : Loss value 9048.54782063
# weight distance : 0.00671293133098
# Iteration 82 : Loss value 9016.98915392
# weight distance : 0.00664160231978
# Iteration 83 : Loss value 8986.02584875
# weight distance : 0.00657171229315
# Iteration 84 : Loss value 8955.640366
# weight distance : 0.00650321711208
# Iteration 85 : Loss value 8925.8158662
# weight distance : 0.00643607442257
# Iteration 86 : Loss value 8896.53617475
# weight distance : 0.006370243568
# Iteration 87 : Loss value 8867.78574917
# weight distance : 0.0063056855065
# Iteration 88 : Loss value 8839.54964823
# weight distance : 0.00624236273294
# Iteration 89 : Loss value 8811.81350291
# weight distance : 0.00618023920526
# Iteration 90 : Loss value 8784.56348901
# weight distance : 0.00611928027495
# Iteration 91 : Loss value 8757.7863013
# weight distance : 0.00605945262129
# Iteration 92 : Loss value 8731.46912915
# weight distance : 0.00600072418923
# Iteration 93 : Loss value 8705.5996335
# weight distance : 0.00594306413064
# Iteration 94 : Loss value 8680.16592515
# weight distance : 0.0058864427487
# Iteration 95 : Loss value 8655.15654416
# weight distance : 0.00583083144534
# Iteration 96 : Loss value 8630.56044044
# weight distance : 0.00577620267136
# Iteration 97 : Loss value 8606.36695537
# weight distance : 0.00572252987933
# Iteration 98 : Loss value 8582.56580439
# weight distance : 0.00566978747884
# Iteration 99 : Loss value 8559.14706052
# weight distance : 0.00561795079412
# Iteration 100 : Loss value 8536.10113874
# weight distance : 0.0055669960239
# Iteration 101 : Loss value 8513.41878121
# weight distance : 0.00551690020326
# Iteration 102 : Loss value 8491.09104319
# weight distance : 0.00546764116744
# Iteration 103 : Loss value 8469.10927978
# weight distance : 0.00541919751755
# Iteration 104 : Loss value 8447.46513324
# weight distance : 0.00537154858787
# Iteration 105 : Loss value 8426.150521
# weight distance : 0.00532467441496
# Iteration 106 : Loss value 8405.15762426
# weight distance : 0.00527855570812
# Iteration 107 : Loss value 8384.47887714
# weight distance : 0.00523317382144
# Iteration 108 : Loss value 8364.1069564
# weight distance : 0.00518851072714
# Iteration 109 : Loss value 8344.03477159
# weight distance : 0.00514454899025
# Iteration 110 : Loss value 8324.25545579
# weight distance : 0.00510127174445
# Iteration 111 : Loss value 8304.76235667
# weight distance : 0.00505866266917
# Iteration 112 : Loss value 8285.54902807
# weight distance : 0.00501670596763
# Iteration 113 : Loss value 8266.60922192
# weight distance : 0.00497538634607
# Iteration 114 : Loss value 8247.93688056
# weight distance : 0.00493468899386
# Iteration 115 : Loss value 8229.52612945
# weight distance : 0.00489459956455
# Iteration 116 : Loss value 8211.37127015
# weight distance : 0.00485510415782
# Iteration 117 : Loss value 8193.46677365
# weight distance : 0.00481618930224
# Iteration 118 : Loss value 8175.80727403
# weight distance : 0.0047778419388
# Iteration 119 : Loss value 8158.3875624
# weight distance : 0.00474004940526
# Iteration 120 : Loss value 8141.20258106
# weight distance : 0.00470279942109
# Iteration 121 : Loss value 8124.24741795
# weight distance : 0.00466608007319
# Iteration 122 : Loss value 8107.51730139
# weight distance : 0.00462987980217
# Iteration 123 : Loss value 8091.007595
# weight distance : 0.00459418738928
# Iteration 124 : Loss value 8074.7137928
# weight distance : 0.00455899194388
# Iteration 125 : Loss value 8058.63151465
# weight distance : 0.00452428289148
# Iteration 126 : Loss value 8042.75650175
# weight distance : 0.0044900499623
# Iteration 127 : Loss value 8027.0846124
# weight distance : 0.00445628318027
# Iteration 128 : Loss value 8011.61181795
# weight distance : 0.00442297285259
# Iteration 129 : Loss value 7996.33419885
# weight distance : 0.00439010955962
# Iteration 130 : Loss value 7981.24794099
# weight distance : 0.00435768414532
# Iteration 131 : Loss value 7966.349332
# weight distance : 0.00432568770797
# Iteration 132 : Loss value 7951.63475793
# weight distance : 0.00429411159135
# Iteration 133 : Loss value 7937.10069987
# weight distance : 0.00426294737629
# Iteration 134 : Loss value 7922.7437308
# weight distance : 0.00423218687252
# Iteration 135 : Loss value 7908.56051258
# weight distance : 0.00420182211084
# Iteration 136 : Loss value 7894.54779301
# weight distance : 0.00417184533572
# Iteration 137 : Loss value 7880.70240302
# weight distance : 0.00414224899805
# Iteration 138 : Loss value 7867.02125401
# weight distance : 0.00411302574828
# Iteration 139 : Loss value 7853.50133523
# weight distance : 0.00408416842979
# Iteration 140 : Loss value 7840.13971131
# weight distance : 0.00405567007256
# Iteration 141 : Loss value 7826.93351986
# weight distance : 0.00402752388701
# Iteration 142 : Loss value 7813.87996919
# weight distance : 0.00399972325818
# Iteration 143 : Loss value 7800.97633608
# weight distance : 0.00397226174007
# Iteration 144 : Loss value 7788.21996366
# weight distance : 0.00394513305023
# Iteration 145 : Loss value 7775.60825935
# weight distance : 0.00391833106449
# Iteration 146 : Loss value 7763.13869292
# weight distance : 0.00389184981203
# Iteration 147 : Loss value 7750.80879454
# weight distance : 0.00386568347048
# Iteration 148 : Loss value 7738.61615301
# weight distance : 0.00383982636129
# Iteration 149 : Loss value 7726.55841394
# weight distance : 0.00381427294529
# Iteration 150 : Loss value 7714.6332781
# weight distance : 0.00378901781834
# Iteration 151 : Loss value 7702.83849976
# weight distance : 0.00376405570721
# Iteration 152 : Loss value 7691.17188511
# weight distance : 0.00373938146556
# Iteration 153 : Loss value 7679.63129075
# weight distance : 0.00371499007013
# Iteration 154 : Loss value 7668.2146222
# weight distance : 0.00369087661698
# Iteration 155 : Loss value 7656.91983252
# weight distance : 0.00366703631797
# Iteration 156 : Loss value 7645.74492092
# weight distance : 0.00364346449726
# Iteration 157 : Loss value 7634.68793142
# weight distance : 0.00362015658801
# Iteration 158 : Loss value 7623.74695163
# weight distance : 0.00359710812917
# Iteration 159 : Loss value 7612.92011147
# weight distance : 0.0035743147624
# Iteration 160 : Loss value 7602.20558202
# weight distance : 0.00355177222906
# Iteration 161 : Loss value 7591.60157433
# weight distance : 0.00352947636735
# Iteration 162 : Loss value 7581.10633836
# weight distance : 0.00350742310949
# Iteration 163 : Loss value 7570.71816187
# weight distance : 0.00348560847909
# Iteration 164 : Loss value 7560.43536941
# weight distance : 0.00346402858852
# Iteration 165 : Loss value 7550.25632129
# weight distance : 0.00344267963641
# Iteration 166 : Loss value 7540.17941265
# weight distance : 0.00342155790524
# Iteration 167 : Loss value 7530.20307249
# weight distance : 0.00340065975897
# Iteration 168 : Loss value 7520.32576277
# weight distance : 0.00337998164082
# Iteration 169 : Loss value 7510.54597755
# weight distance : 0.00335952007108
# Iteration 170 : Loss value 7500.86224212
# weight distance : 0.00333927164494
# Iteration 171 : Loss value 7491.2731122
# weight distance : 0.00331923303054
# Iteration 172 : Loss value 7481.77717311
# weight distance : 0.00329940096691
# Iteration 173 : Loss value 7472.37303905
# weight distance : 0.0032797722621
# Iteration 174 : Loss value 7463.0593523
# weight distance : 0.00326034379132
# Iteration 175 : Loss value 7453.83478256
# weight distance : 0.00324111249515
# Iteration 176 : Loss value 7444.69802617
# weight distance : 0.00322207537781
# Iteration 177 : Loss value 7435.6478055
# weight distance : 0.00320322950549
# Iteration 178 : Loss value 7426.68286827
# weight distance : 0.00318457200469
# Iteration 179 : Loss value 7417.8019869
# weight distance : 0.0031661000607
# Iteration 180 : Loss value 7409.00395791
# weight distance : 0.00314781091602
# Iteration 181 : Loss value 7400.2876013
# weight distance : 0.00312970186895
# Iteration 182 : Loss value 7391.65176
# weight distance : 0.00311177027207
# Iteration 183 : Loss value 7383.09529926
# weight distance : 0.00309401353095
# Iteration 184 : Loss value 7374.61710616
# weight distance : 0.00307642910275
# Iteration 185 : Loss value 7366.21608904
# weight distance : 0.00305901449491
# Iteration 186 : Loss value 7357.89117698
# weight distance : 0.00304176726393
# Iteration 187 : Loss value 7349.64131933
# weight distance : 0.00302468501412
# Iteration 188 : Loss value 7341.4654852
# weight distance : 0.00300776539638
# Iteration 189 : Loss value 7333.36266301
# weight distance : 0.00299100610714
# Iteration 190 : Loss value 7325.33186
# weight distance : 0.00297440488713
# Iteration 191 : Loss value 7317.37210183
# weight distance : 0.00295795952039
# Iteration 192 : Loss value 7309.4824321
# weight distance : 0.00294166783314
# Iteration 193 : Loss value 7301.66191195
# weight distance : 0.00292552769283
# Iteration 194 : Loss value 7293.90961969
# weight distance : 0.00290953700708
# Iteration 195 : Loss value 7286.22465033
# weight distance : 0.00289369372278
# Iteration 196 : Loss value 7278.60611525
# weight distance : 0.00287799582511
# Iteration 197 : Loss value 7271.05314182
# weight distance : 0.00286244133665
# Iteration 198 : Loss value 7263.56487301
# weight distance : 0.00284702831648
# Iteration 199 : Loss value 7256.14046705
# weight distance : 0.00283175485937
# Iteration 200 : Loss value 7248.7790971
# weight distance : 0.00281661909488
# Iteration 201 : Loss value 7241.4799509
# weight distance : 0.0028016191866
# Iteration 202 : Loss value 7234.24223044
# weight distance : 0.00278675333136
# Iteration 203 : Loss value 7227.06515164
# weight distance : 0.00277201975843
# Iteration 204 : Loss value 7219.94794407
# weight distance : 0.00275741672883
# Iteration 205 : Loss value 7212.88985063
# weight distance : 0.00274294253456
# Iteration 206 : Loss value 7205.89012723
# weight distance : 0.00272859549791
# Iteration 207 : Loss value 7198.94804258
# weight distance : 0.0027143739708
# Iteration 208 : Loss value 7192.06287783
# weight distance : 0.00270027633408
# Iteration 209 : Loss value 7185.23392635
# weight distance : 0.00268630099691
# Iteration 210 : Loss value 7178.46049345
# weight distance : 0.00267244639614
# Iteration 211 : Loss value 7171.74189614
# weight distance : 0.00265871099564
# Iteration 212 : Loss value 7165.07746287
# weight distance : 0.00264509328576
# Iteration 213 : Loss value 7158.46653327
# weight distance : 0.00263159178275
# Iteration 214 : Loss value 7151.90845794
# weight distance : 0.00261820502817
# Iteration 215 : Loss value 7145.40259823
# weight distance : 0.00260493158832
# Iteration 216 : Loss value 7138.94832596
# weight distance : 0.00259177005378
# Iteration 217 : Loss value 7132.54502327
# weight distance : 0.00257871903881
# Iteration 218 : Loss value 7126.19208234
# weight distance : 0.00256577718089
# Iteration 219 : Loss value 7119.88890526
# weight distance : 0.0025529431402
# Iteration 220 : Loss value 7113.63490374
# weight distance : 0.00254021559916
# Iteration 221 : Loss value 7107.42949897
# weight distance : 0.00252759326195
# Iteration 222 : Loss value 7101.27212144
# weight distance : 0.00251507485402
# Iteration 223 : Loss value 7095.16221067
# weight distance : 0.00250265912173
# Iteration 224 : Loss value 7089.09921513
# weight distance : 0.00249034483182
# Iteration 225 : Loss value 7083.08259199
# weight distance : 0.00247813077105
# Iteration 226 : Loss value 7077.11180697
# weight distance : 0.00246601574576
# Iteration 227 : Loss value 7071.18633417
# weight distance : 0.00245399858146
# Iteration 228 : Loss value 7065.30565589
# weight distance : 0.00244207812248
# Iteration 229 : Loss value 7059.46926248
# weight distance : 0.00243025323154
# Iteration 230 : Loss value 7053.67665221
# weight distance : 0.0024185227894
# Iteration 231 : Loss value 7047.92733103
# weight distance : 0.00240688569448
# Iteration 232 : Loss value 7042.22081253
# weight distance : 0.00239534086255
# Iteration 233 : Loss value 7036.55661771
# weight distance : 0.0023838872263
# Iteration 234 : Loss value 7030.93427485
# weight distance : 0.0023725237351
# Iteration 235 : Loss value 7025.35331942
# weight distance : 0.00236124935459
# Iteration 236 : Loss value 7019.81329386
# weight distance : 0.00235006306642
# Iteration 237 : Loss value 7014.31374753
# weight distance : 0.00233896386787
# Iteration 238 : Loss value 7008.85423652
# weight distance : 0.00232795077161
# Iteration 239 : Loss value 7003.43432354
# weight distance : 0.00231702280536
# Iteration 240 : Loss value 6998.05357781
# weight distance : 0.0023061790116
# Iteration 241 : Loss value 6992.71157492
# weight distance : 0.00229541844731
# Iteration 242 : Loss value 6987.40789672
# weight distance : 0.00228474018367
# Iteration 243 : Loss value 6982.14213117
# weight distance : 0.00227414330577
# Iteration 244 : Loss value 6976.9138723
# weight distance : 0.0022636269124
# Iteration 245 : Loss value 6971.72272002
# weight distance : 0.00225319011572
# Iteration 246 : Loss value 6966.56828006
# weight distance : 0.00224283204108
# Iteration 247 : Loss value 6961.45016384
# weight distance : 0.00223255182671
# Iteration 248 : Loss value 6956.36798837
# weight distance : 0.00222234862352
# Iteration 249 : Loss value 6951.32137617
# weight distance : 0.00221222159482
# Iteration 250 : Loss value 6946.30995513
# weight distance : 0.00220216991614
# Iteration 251 : Loss value 6941.33335845
# weight distance : 0.00219219277498
# Iteration 252 : Loss value 6936.39122452
# weight distance : 0.00218228937056
# Iteration 253 : Loss value 6931.48319684
# weight distance : 0.00217245891367
# Iteration 254 : Loss value 6926.60892392
# weight distance : 0.00216270062638
# Iteration 255 : Loss value 6921.7680592
# weight distance : 0.00215301374192
# Iteration 256 : Loss value 6916.96026097
# weight distance : 0.00214339750439
# Iteration 257 : Loss value 6912.18519224
# weight distance : 0.00213385116863
# Iteration 258 : Loss value 6907.44252072
# weight distance : 0.002124374
# Iteration 259 : Loss value 6902.73191869
# weight distance : 0.00211496527419
# Iteration 260 : Loss value 6898.05306296
# weight distance : 0.00210562427703
# Iteration 261 : Loss value 6893.40563472
# weight distance : 0.00209635030434
# Iteration 262 : Loss value 6888.78931957
# weight distance : 0.0020871426617
# Iteration 263 : Loss value 6884.20380734
# weight distance : 0.00207800066434
# Iteration 264 : Loss value 6879.6487921
# weight distance : 0.00206892363693
# Iteration 265 : Loss value 6875.12397202
# weight distance : 0.0020599109134
# Iteration 266 : Loss value 6870.62904935
# weight distance : 0.00205096183683
# Iteration 267 : Loss value 6866.16373032
# weight distance : 0.00204207575925
# Iteration 268 : Loss value 6861.72772509
# weight distance : 0.0020332520415
# Iteration 269 : Loss value 6857.32074768
# weight distance : 0.00202449005308
# Iteration 270 : Loss value 6852.94251589
# weight distance : 0.00201578917199
# Iteration 271 : Loss value 6848.59275126
# weight distance : 0.00200714878458
# Iteration 272 : Loss value 6844.27117899
# weight distance : 0.00199856828545
# Iteration 273 : Loss value 6839.97752789
# weight distance : 0.00199004707726
# Iteration 274 : Loss value 6835.7115303
# weight distance : 0.00198158457059
# Iteration 275 : Loss value 6831.47292208
# weight distance : 0.00197318018387
# Iteration 276 : Loss value 6827.26144249
# weight distance : 0.00196483334317
# Iteration 277 : Loss value 6823.07683417
# weight distance : 0.00195654348213
# Iteration 278 : Loss value 6818.91884307
# weight distance : 0.00194831004182
# Iteration 279 : Loss value 6814.78721843
# weight distance : 0.00194013247057
# Iteration 280 : Loss value 6810.68171267
# weight distance : 0.00193201022392
# Iteration 281 : Loss value 6806.60208139
# weight distance : 0.00192394276447
# Iteration 282 : Loss value 6802.54808328
# weight distance : 0.00191592956174
# Iteration 283 : Loss value 6798.5194801
# weight distance : 0.00190797009211
# Iteration 284 : Loss value 6794.51603662
# weight distance : 0.00190006383865
# Iteration 285 : Loss value 6790.53752055
# weight distance : 0.00189221029106
# Iteration 286 : Loss value 6786.58370255
# weight distance : 0.00188440894553
# Iteration 287 : Loss value 6782.65435611
# weight distance : 0.00187665930464
# Iteration 288 : Loss value 6778.74925755
# weight distance : 0.00186896087729
# Iteration 289 : Loss value 6774.868186
# weight distance : 0.00186131317854
# Iteration 290 : Loss value 6771.01092327
# weight distance : 0.00185371572957
# Iteration 291 : Loss value 6767.1772539
# weight distance : 0.00184616805755
# Iteration 292 : Loss value 6763.36696507
# weight distance : 0.00183866969554
# Iteration 293 : Loss value 6759.57984656
# weight distance : 0.00183122018242
# Iteration 294 : Loss value 6755.81569072
# weight distance : 0.0018238190628
# Iteration 295 : Loss value 6752.07429243
# weight distance : 0.00181646588688
# Iteration 296 : Loss value 6748.35544906
# weight distance : 0.00180916021043
# Iteration 297 : Loss value 6744.65896042
# weight distance : 0.00180190159467
# Iteration 298 : Loss value 6740.98462875
# weight distance : 0.00179468960618
# Iteration 299 : Loss value 6737.33225865
# weight distance : 0.00178752381683
# Iteration 300 : Loss value 6733.70165706
# weight distance : 0.00178040380369
# Iteration 301 : Loss value 6730.09263323
# weight distance : 0.00177332914896
# Iteration 302 : Loss value 6726.50499869
# weight distance : 0.00176629943987
# Iteration 303 : Loss value 6722.93856719
# weight distance : 0.00175931426864
# Iteration 304 : Loss value 6719.39315469
# weight distance : 0.00175237323237
# Iteration 305 : Loss value 6715.86857931
# weight distance : 0.00174547593297
# Iteration 306 : Loss value 6712.36466131
# weight distance : 0.00173862197712
# Iteration 307 : Loss value 6708.88122306
# weight distance : 0.00173181097615
# Iteration 308 : Loss value 6705.41808899
# weight distance : 0.00172504254601
# Iteration 309 : Loss value 6701.9750856
# weight distance : 0.00171831630718
# Iteration 310 : Loss value 6698.55204138
# weight distance : 0.00171163188459
# Iteration 311 : Loss value 6695.1487868
# weight distance : 0.00170498890759
# Iteration 312 : Loss value 6691.7651543
# weight distance : 0.00169838700988
# Iteration 313 : Loss value 6688.40097823
# weight distance : 0.0016918258294
# Iteration 314 : Loss value 6685.05609486
# weight distance : 0.00168530500831
# Iteration 315 : Loss value 6681.73034231
# weight distance : 0.00167882419292
# Iteration 316 : Loss value 6678.42356054
# weight distance : 0.00167238303363
# Iteration 317 : Loss value 6675.13559134
# weight distance : 0.00166598118486
# Iteration 318 : Loss value 6671.8662783
# weight distance : 0.001659618305
# Iteration 319 : Loss value 6668.61546674
# weight distance : 0.00165329405635
# Iteration 320 : Loss value 6665.38300376
# weight distance : 0.00164700810506
# Iteration 321 : Loss value 6662.16873813
# weight distance : 0.0016407601211
# Iteration 322 : Loss value 6658.97252036
# weight distance : 0.00163454977815
# Iteration 323 : Loss value 6655.79420259
# weight distance : 0.00162837675361
# Iteration 324 : Loss value 6652.63363861
# weight distance : 0.00162224072851
# Iteration 325 : Loss value 6649.49068384
# weight distance : 0.00161614138745
# Iteration 326 : Loss value 6646.36519529
# weight distance : 0.00161007841858
# Iteration 327 : Loss value 6643.25703155
# weight distance : 0.00160405151355
# Iteration 328 : Loss value 6640.16605275
# weight distance : 0.00159806036742
# Iteration 329 : Loss value 6637.09212057
# weight distance : 0.00159210467865
# Iteration 330 : Loss value 6634.03509819
# weight distance : 0.00158618414903
# Iteration 331 : Loss value 6630.99485027
# weight distance : 0.00158029848368
# Iteration 332 : Loss value 6627.97124295
# weight distance : 0.00157444739092
# Iteration 333 : Loss value 6624.96414381
# weight distance : 0.0015686305823
# Iteration 334 : Loss value 6621.97342188
# weight distance : 0.00156284777253
# Iteration 335 : Loss value 6618.99894757
# weight distance : 0.00155709867944
# Iteration 336 : Loss value 6616.0405927
# weight distance : 0.0015513830239
# Iteration 337 : Loss value 6613.09823045
# weight distance : 0.00154570052986
# Iteration 338 : Loss value 6610.17173536
# weight distance : 0.00154005092421
# Iteration 339 : Loss value 6607.2609833
# weight distance : 0.00153443393684
# Iteration 340 : Loss value 6604.36585145
# weight distance : 0.00152884930049
# Iteration 341 : Loss value 6601.48621829
# weight distance : 0.00152329675083
# Iteration 342 : Loss value 6598.6219636
# weight distance : 0.00151777602631
# Iteration 343 : Loss value 6595.7729684
# weight distance : 0.0015122868682
# Iteration 344 : Loss value 6592.93911497
# weight distance : 0.00150682902051
# Iteration 345 : Loss value 6590.12028682
# weight distance : 0.00150140222999
# Iteration 346 : Loss value 6587.31636866
# weight distance : 0.00149600624605
# Iteration 347 : Loss value 6584.52724641
# weight distance : 0.00149064082076
# Iteration 348 : Loss value 6581.75280719
# weight distance : 0.00148530570879
# Iteration 349 : Loss value 6578.99293924
# weight distance : 0.0014800006674
# Iteration 350 : Loss value 6576.24753201
# weight distance : 0.00147472545637
# Iteration 351 : Loss value 6573.51647603
# weight distance : 0.00146947983801
# Iteration 352 : Loss value 6570.799663
# weight distance : 0.00146426357711
# Iteration 353 : Loss value 6568.09698568
# weight distance : 0.00145907644088
# Iteration 354 : Loss value 6565.40833797
# weight distance : 0.00145391819897
# Iteration 355 : Loss value 6562.73361482
# weight distance : 0.00144878862338
# Iteration 356 : Loss value 6560.07271224
# weight distance : 0.00144368748849
# Iteration 357 : Loss value 6557.42552732
# weight distance : 0.00143861457099
# Iteration 358 : Loss value 6554.79195816
# weight distance : 0.00143356964984
# Iteration 359 : Loss value 6552.17190389
# weight distance : 0.00142855250629
# Iteration 360 : Loss value 6549.56526467
# weight distance : 0.0014235629238
# Iteration 361 : Loss value 6546.97194163
# weight distance : 0.00141860068805
# Iteration 362 : Loss value 6544.3918369
# weight distance : 0.00141366558688
# Iteration 363 : Loss value 6541.82485359
# weight distance : 0.00140875741028
# Iteration 364 : Loss value 6539.27089576
# weight distance : 0.00140387595036
# Iteration 365 : Loss value 6536.72986843
# weight distance : 0.00139902100133
# Iteration 366 : Loss value 6534.20167754
# weight distance : 0.00139419235946
# Iteration 367 : Loss value 6531.68622996
# weight distance : 0.00138938982307
# Iteration 368 : Loss value 6529.1834335
# weight distance : 0.00138461319248
# Iteration 369 : Loss value 6526.69319684
# weight distance : 0.00137986227002
# Iteration 370 : Loss value 6524.21542955
# weight distance : 0.00137513685995
# Iteration 371 : Loss value 6521.75004211
# weight distance : 0.00137043676852
# Iteration 372 : Loss value 6519.29694585
# weight distance : 0.00136576180385
# Iteration 373 : Loss value 6516.85605296
# weight distance : 0.00136111177598
# Iteration 374 : Loss value 6514.42727647
# weight distance : 0.00135648649683
# Iteration 375 : Loss value 6512.01053026
# weight distance : 0.00135188578012
# Iteration 376 : Loss value 6509.60572904
# weight distance : 0.00134730944145
# Iteration 377 : Loss value 6507.21278832
# weight distance : 0.00134275729819
# Iteration 378 : Loss value 6504.83162444
# weight distance : 0.00133822916948
# Iteration 379 : Loss value 6502.46215452
# weight distance : 0.00133372487626
# Iteration 380 : Loss value 6500.10429648
# weight distance : 0.00132924424116
# Iteration 381 : Loss value 6497.757969
# weight distance : 0.00132478708855
# Iteration 382 : Loss value 6495.42309155
# weight distance : 0.0013203532445
# Iteration 383 : Loss value 6493.09958436
# weight distance : 0.00131594253673
# Iteration 384 : Loss value 6490.78736838
# weight distance : 0.00131155479465
# Iteration 385 : Loss value 6488.48636534
# weight distance : 0.00130718984927
# Iteration 386 : Loss value 6486.19649769
# weight distance : 0.00130284753324
# Iteration 387 : Loss value 6483.91768858
# weight distance : 0.00129852768079
# Iteration 388 : Loss value 6481.64986192
# weight distance : 0.00129423012773
# Iteration 389 : Loss value 6479.3929423
# weight distance : 0.00128995471145
# Iteration 390 : Loss value 6477.146855
# weight distance : 0.00128570127083
# Iteration 391 : Loss value 6474.91152602
# weight distance : 0.00128146964633
# Iteration 392 : Loss value 6472.68688201
# weight distance : 0.00127725967987
# Iteration 393 : Loss value 6470.47285032
# weight distance : 0.00127307121489
# Iteration 394 : Loss value 6468.26935896
# weight distance : 0.00126890409626
# Iteration 395 : Loss value 6466.07633659
# weight distance : 0.00126475817034
# Iteration 396 : Loss value 6463.89371253
# weight distance : 0.0012606332849
# Iteration 397 : Loss value 6461.72141674
# weight distance : 0.00125652928913
# Iteration 398 : Loss value 6459.55937981
# weight distance : 0.00125244603364
# Iteration 399 : Loss value 6457.40753298
# weight distance : 0.0012483833704
# Iteration 400 : Loss value 6455.2658081
# weight distance : 0.00124434115277
# Iteration 401 : Loss value 6453.13413762
# weight distance : 0.00124031923545
# Iteration 402 : Loss value 6451.01245461
# weight distance : 0.00123631747449
# Iteration 403 : Loss value 6448.90069275
# weight distance : 0.00123233572726
# Iteration 404 : Loss value 6446.7987863
# weight distance : 0.00122837385241
# Iteration 405 : Loss value 6444.70667012
# weight distance : 0.00122443170994
# Iteration 406 : Loss value 6442.62427962
# weight distance : 0.00122050916107
# Iteration 407 : Loss value 6440.55155083
# weight distance : 0.00121660606831
# Iteration 408 : Loss value 6438.48842031
# weight distance : 0.00121272229543
# Iteration 409 : Loss value 6436.4348252
# weight distance : 0.00120885770742
# Iteration 410 : Loss value 6434.39070318
# weight distance : 0.00120501217048
# Iteration 411 : Loss value 6432.35599249
# weight distance : 0.00120118555205
# Iteration 412 : Loss value 6430.33063191
# weight distance : 0.00119737772073
# Iteration 413 : Loss value 6428.31456076
# weight distance : 0.00119358854633
# Iteration 414 : Loss value 6426.30771889
# weight distance : 0.00118981789981
# Iteration 415 : Loss value 6424.31004665
# weight distance : 0.00118606565328
# Iteration 416 : Loss value 6422.32148495
# weight distance : 0.00118233168002
# Iteration 417 : Loss value 6420.34197517
# weight distance : 0.00117861585439
# Iteration 418 : Loss value 6418.37145924
# weight distance : 0.00117491805192
# Iteration 419 : Loss value 6416.40987956
# weight distance : 0.00117123814921
# Iteration 420 : Loss value 6414.45717904
# weight distance : 0.00116757602397
# Iteration 421 : Loss value 6412.51330107
# weight distance : 0.00116393155497
# Iteration 422 : Loss value 6410.57818953
# weight distance : 0.00116030462207
# Iteration 423 : Loss value 6408.6517888
# weight distance : 0.00115669510618
# Iteration 424 : Loss value 6406.7340437
# weight distance : 0.00115310288925
# Iteration 425 : Loss value 6404.82489955
# weight distance : 0.00114952785427
# Iteration 426 : Loss value 6402.92430211
# weight distance : 0.00114596988525
# Iteration 427 : Loss value 6401.03219762
# weight distance : 0.0011424288672
# Iteration 428 : Loss value 6399.14853276
# weight distance : 0.00113890468615
# Iteration 429 : Loss value 6397.27325467
# weight distance : 0.00113539722911
# Iteration 430 : Loss value 6395.40631092
# weight distance : 0.00113190638408
# Iteration 431 : Loss value 6393.54764955
# weight distance : 0.00112843204001
# Iteration 432 : Loss value 6391.697219
# weight distance : 0.00112497408682
# Iteration 433 : Loss value 6389.85496816
# weight distance : 0.00112153241539
# Iteration 434 : Loss value 6388.02084634
# weight distance : 0.0011181069175
# Iteration 435 : Loss value 6386.19480329
# weight distance : 0.0011146974859
# Iteration 436 : Loss value 6384.37678915
# weight distance : 0.00111130401423
# Iteration 437 : Loss value 6382.56675448
# weight distance : 0.00110792639707
# Iteration 438 : Loss value 6380.76465027
# weight distance : 0.00110456452986
# Iteration 439 : Loss value 6378.97042789
# weight distance : 0.00110121830895
# Iteration 440 : Loss value 6377.18403912
# weight distance : 0.00109788763157
# Iteration 441 : Loss value 6375.40543612
# weight distance : 0.00109457239583
# Iteration 442 : Loss value 6373.63457148
# weight distance : 0.00109127250068
# Iteration 443 : Loss value 6371.87139813
# weight distance : 0.00108798784593
# Iteration 444 : Loss value 6370.11586942
# weight distance : 0.00108471833225
# Iteration 445 : Loss value 6368.36793906
# weight distance : 0.00108146386113
# Iteration 446 : Loss value 6366.62756115
# weight distance : 0.00107822433489
# Iteration 447 : Loss value 6364.89469015
# weight distance : 0.00107499965666
# Iteration 448 : Loss value 6363.1692809
# weight distance : 0.0010717897304
# Iteration 449 : Loss value 6361.45128858
# weight distance : 0.00106859446085
# Iteration 450 : Loss value 6359.74066875
# weight distance : 0.00106541375355
# Iteration 451 : Loss value 6358.03737733
# weight distance : 0.00106224751483
# Iteration 452 : Loss value 6356.34137059
# weight distance : 0.00105909565179
# Iteration 453 : Loss value 6354.65260514
# weight distance : 0.00105595807231
# Iteration 454 : Loss value 6352.97103795
# weight distance : 0.00105283468502
# Iteration 455 : Loss value 6351.29662631
# weight distance : 0.0010497253993
# Iteration 456 : Loss value 6349.62932787
# weight distance : 0.00104663012529
# Iteration 457 : Loss value 6347.96910062
# weight distance : 0.00104354877385
# Iteration 458 : Loss value 6346.31590286
# weight distance : 0.00104048125659
# Iteration 459 : Loss value 6344.66969324
# weight distance : 0.00103742748583
# Iteration 460 : Loss value 6343.03043071
# weight distance : 0.00103438737461
# Iteration 461 : Loss value 6341.39807458
# weight distance : 0.00103136083668
# Iteration 462 : Loss value 6339.77258444
# weight distance : 0.00102834778649
# Iteration 463 : Loss value 6338.15392023
# weight distance : 0.00102534813918
# Iteration 464 : Loss value 6336.54204217
# weight distance : 0.00102236181059
# Iteration 465 : Loss value 6334.93691082
# weight distance : 0.00101938871723
# Iteration 466 : Loss value 6333.33848702
# weight distance : 0.00101642877629
# Iteration 467 : Loss value 6331.74673194
# weight distance : 0.00101348190562
# Iteration 468 : Loss value 6330.16160702
# weight distance : 0.00101054802374
# Iteration 469 : Loss value 6328.58307403
# weight distance : 0.00100762704982
# Iteration 470 : Loss value 6327.01109502
# weight distance : 0.00100471890367
# Iteration 471 : Loss value 6325.44563233
# weight distance : 0.00100182350576
# Iteration 472 : Loss value 6323.88664858
# weight distance : 0.000998940777182
# Iteration 473 : Loss value 6322.33410669
# weight distance : 0.000996070639654
# Iteration 474 : Loss value 6320.78796987
# weight distance : 0.000993213015526
# Iteration 475 : Loss value 6319.24820159
# weight distance : 0.000990367827759
# Iteration 476 : Loss value 6317.71476561
# weight distance : 0.000987534999927
# Iteration 477 : Loss value 6316.18762598
# weight distance : 0.000984714456208
# Iteration 478 : Loss value 6314.66674698
# weight distance : 0.000981906121379
# Iteration 479 : Loss value 6313.1520932
# weight distance : 0.00097910992081
# Iteration 480 : Loss value 6311.64362949
# weight distance : 0.000976325780457
# Iteration 481 : Loss value 6310.14132095
# weight distance : 0.000973553626861
# Iteration 482 : Loss value 6308.64513295
# weight distance : 0.000970793387135
# Iteration 483 : Loss value 6307.15503113
# weight distance : 0.000968044988965
# Iteration 484 : Loss value 6305.67098136
# weight distance : 0.000965308360601
# Iteration 485 : Loss value 6304.1929498
# weight distance : 0.000962583430853
# Iteration 486 : Loss value 6302.72090284
# weight distance : 0.000959870129086
# Iteration 487 : Loss value 6301.25480713
# weight distance : 0.000957168385213
# Iteration 488 : Loss value 6299.79462955
# weight distance : 0.000954478129691
# Iteration 489 : Loss value 6298.34033724
# weight distance : 0.000951799293515
# Iteration 490 : Loss value 6296.89189759
# weight distance : 0.000949131808214
# Iteration 491 : Loss value 6295.44927822
# weight distance : 0.000946475605846
# Iteration 492 : Loss value 6294.01244699
# weight distance : 0.000943830618992
# Iteration 493 : Loss value 6292.58137199
# weight distance : 0.000941196780751
# Iteration 494 : Loss value 6291.15602156
# weight distance : 0.000938574024736
# Iteration 495 : Loss value 6289.73636425
# weight distance : 0.000935962285069
# Iteration 496 : Loss value 6288.32236886
# weight distance : 0.000933361496376
# Iteration 497 : Loss value 6286.91400442
# weight distance : 0.000930771593781
# Iteration 498 : Loss value 6285.51124016
# weight distance : 0.000928192512905
# Iteration 499 : Loss value 6284.11404555
# weight distance : 0.000925624189857
# Iteration 500 : Loss value 6282.72239029
# weight distance : 0.000923066561233
# Iteration 501 : Loss value 6281.33624427
# weight distance : 0.000920519564108
# Iteration 502 : Loss value 6279.95557764
# weight distance : 0.000917983136035
# Iteration 503 : Loss value 6278.58036073
# weight distance : 0.00091545721504
# Iteration 504 : Loss value 6277.21056409
# weight distance : 0.000912941739614
# Iteration 505 : Loss value 6275.84615849
# weight distance : 0.000910436648713
# Iteration 506 : Loss value 6274.48711491
# weight distance : 0.000907941881753
# Iteration 507 : Loss value 6273.13340453
# weight distance : 0.000905457378603
# Iteration 508 : Loss value 6271.78499874
# weight distance : 0.000902983079583
# Iteration 509 : Loss value 6270.44186913
# weight distance : 0.000900518925462
# Iteration 510 : Loss value 6269.10398749
# weight distance : 0.000898064857449
# Iteration 511 : Loss value 6267.77132583
# weight distance : 0.000895620817192
# Iteration 512 : Loss value 6266.44385633
# weight distance : 0.000893186746775
# Iteration 513 : Loss value 6265.12155138
# weight distance : 0.000890762588709
# Iteration 514 : Loss value 6263.80438357
# weight distance : 0.000888348285937
# Iteration 515 : Loss value 6262.49232567
# weight distance : 0.000885943781819
# Iteration 516 : Loss value 6261.18535065
# weight distance : 0.000883549020138
# Iteration 517 : Loss value 6259.88343168
# weight distance : 0.000881163945092
# Iteration 518 : Loss value 6258.58654209
# weight distance : 0.000878788501288
# Iteration 519 : Loss value 6257.29465541
# weight distance : 0.000876422633742
# Iteration 520 : Loss value 6256.00774537
# weight distance : 0.000874066287875
# Iteration 521 : Loss value 6254.72578587
# weight distance : 0.000871719409508
# Iteration 522 : Loss value 6253.44875098
# weight distance : 0.000869381944857
# Iteration 523 : Loss value 6252.17661496
# weight distance : 0.000867053840534
# Iteration 524 : Loss value 6250.90935226
# weight distance : 0.000864735043539
# Iteration 525 : Loss value 6249.64693748
# weight distance : 0.00086242550126
# Iteration 526 : Loss value 6248.38934542
# weight distance : 0.000860125161467
# Iteration 527 : Loss value 6247.13655105
# weight distance : 0.000857833972308
# Iteration 528 : Loss value 6245.88852949
# weight distance : 0.00085555188231
# Iteration 529 : Loss value 6244.64525606
# weight distance : 0.00085327884037
# Iteration 530 : Loss value 6243.40670622
# weight distance : 0.000851014795758
# Iteration 531 : Loss value 6242.17285563
# weight distance : 0.000848759698107
# Iteration 532 : Loss value 6240.94368008
# weight distance : 0.000846513497415
# Iteration 533 : Loss value 6239.71915556
# weight distance : 0.000844276144039
# Iteration 534 : Loss value 6238.4992582
# weight distance : 0.000842047588693
# Iteration 535 : Loss value 6237.2839643
# weight distance : 0.000839827782445
# Iteration 536 : Loss value 6236.07325031
# weight distance : 0.000837616676712
# Iteration 537 : Loss value 6234.86709285
# weight distance : 0.000835414223261
# Iteration 538 : Loss value 6233.6654687
# weight distance : 0.000833220374201
# Iteration 539 : Loss value 6232.4683548
# weight distance : 0.000831035081984
# Iteration 540 : Loss value 6231.27572822
# weight distance : 0.0008288582994
# Iteration 541 : Loss value 6230.0875662
# weight distance : 0.000826689979575
# Iteration 542 : Loss value 6228.90384615
# weight distance : 0.000824530075966
# Iteration 543 : Loss value 6227.72454559
# weight distance : 0.000822378542361
# Iteration 544 : Loss value 6226.54964224
# weight distance : 0.000820235332876
# Iteration 545 : Loss value 6225.37911392
# weight distance : 0.000818100401949
# Iteration 546 : Loss value 6224.21293862
# weight distance : 0.000815973704341
# Iteration 547 : Loss value 6223.05109449
# weight distance : 0.00081385519513
# Iteration 548 : Loss value 6221.8935598
# weight distance : 0.000811744829712
# Iteration 549 : Loss value 6220.74031298
# weight distance : 0.000809642563794
# Iteration 550 : Loss value 6219.59133258
# weight distance : 0.000807548353395
# Iteration 551 : Loss value 6218.44659732
# weight distance : 0.000805462154841
# Iteration 552 : Loss value 6217.30608605
# weight distance : 0.000803383924763
# Iteration 553 : Loss value 6216.16977775
# weight distance : 0.000801313620096
# Iteration 554 : Loss value 6215.03765154
# weight distance : 0.000799251198073
# Iteration 555 : Loss value 6213.90968668
# weight distance : 0.000797196616226
# Iteration 556 : Loss value 6212.78586257
# weight distance : 0.000795149832383
# Iteration 557 : Loss value 6211.66615873
# weight distance : 0.000793110804661
# Iteration 558 : Loss value 6210.55055484
# weight distance : 0.00079107949147
# Iteration 559 : Loss value 6209.43903068
# weight distance : 0.000789055851508
# Iteration 560 : Loss value 6208.33156619
# weight distance : 0.000787039843755
# Iteration 561 : Loss value 6207.2281414
# weight distance : 0.000785031427478
# Iteration 562 : Loss value 6206.12873652
# weight distance : 0.00078303056222
# Iteration 563 : Loss value 6205.03333185
# weight distance : 0.000781037207806
# Iteration 564 : Loss value 6203.94190784
# weight distance : 0.000779051324335
# Iteration 565 : Loss value 6202.85444503
# weight distance : 0.000777072872178
# Iteration 566 : Loss value 6201.77092414
# weight distance : 0.00077510181198
# Iteration 567 : Loss value 6200.69132596
# weight distance : 0.000773138104654
# Iteration 568 : Loss value 6199.61563143
# weight distance : 0.000771181711378
# Iteration 569 : Loss value 6198.54382161
# weight distance : 0.000769232593597
# Iteration 570 : Loss value 6197.47587769
# weight distance : 0.000767290713017
# Iteration 571 : Loss value 6196.41178094
# weight distance : 0.000765356031605
# Iteration 572 : Loss value 6195.3515128
# weight distance : 0.000763428511584
# Iteration 573 : Loss value 6194.2950548
# weight distance : 0.000761508115435
# Iteration 574 : Loss value 6193.24238858
# weight distance : 0.000759594805892
# Iteration 575 : Loss value 6192.19349592
# weight distance : 0.00075768854594
# Iteration 576 : Loss value 6191.14835869
# weight distance : 0.000755789298815
# Iteration 577 : Loss value 6190.1069589
# weight distance : 0.000753897028001
# Iteration 578 : Loss value 6189.06927864
# weight distance : 0.000752011697224
# Iteration 579 : Loss value 6188.03530014
# weight distance : 0.000750133270458
# Iteration 580 : Loss value 6187.00500574
# weight distance : 0.000748261711916
# Iteration 581 : Loss value 6185.97837788
# weight distance : 0.000746396986051
# Iteration 582 : Loss value 6184.9553991
# weight distance : 0.000744539057554
# Iteration 583 : Loss value 6183.93605208
# weight distance : 0.000742687891352
# Iteration 584 : Loss value 6182.92031957
# weight distance : 0.000740843452605
# Iteration 585 : Loss value 6181.90818446
# weight distance : 0.000739005706706
# Iteration 586 : Loss value 6180.89962973
# weight distance : 0.000737174619277
# Iteration 587 : Loss value 6179.89463846
# weight distance : 0.000735350156168
# Iteration 588 : Loss value 6178.89319386
# weight distance : 0.000733532283458
# Iteration 589 : Loss value 6177.8952792

# %%
model.assess()
model.load_data("testing", testX, testY);
model.makeY(2);
model.assess()
model.plotLoss('training loss', 'testing loss')
# Out:
# Accuracy : 0.970016666667
# 0 / 1 loss : [[ 0.02998333]]
# Loading data testing complete....
# Testing Data : Only looking at class 2!!!
# Accuracy : 0.9711
# 0 / 1 loss : [[ 0.0289]]

# %%
model.lossSet = model.lossSet/60000
model.testLossSet = model.testLossSet/10000
red_star = matplotlib.pyplot.plot(np.arange(0, model.iter), model.lossSet[0:model.iter]/60000, color="red", hold = True, linewidth=2.0)
blue_star = matplotlib.pyplot.plot(np.arange(0, model.iter), model.testLossSet[0:model.iter]/10000, hold = True, color="blue", linewidth=2.0)
matplotlib.pyplot.savefig("RP_plotA.png", transparent = True)
